# %% [markdown]
# # Long Short-Term Memory Machine Learning Model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.losses import MeanSquaredError

# !pip install tensorflow-addons
from tensorflow_addons.metrics import RSquare

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Mounted at /content/drive

# %%
# Load your dataset into a pandas

# ------------------------------- ATTEMPT 1 -------------------------------
df_file_path = folder_path = '/content/drive/My Drive/Colab Notebooks/Data/Machine Learning Dataset.csv'
# df_file_path = folder_path = '/content/drive/My Drive/Colab Notebooks/Data/Machine Learning Dataset (Date).csv'
# -------------------------------------------------------------------------

# ------------------------------- ATTEMPT 2 -------------------------------
# df_file_path = folder_path = '/content/drive/My Drive/Colab Notebooks/Data/Machine Learning Dataset Extended.csv'
# df_file_path = folder_path = '/content/drive/My Drive/Colab Notebooks/Data/Machine Learning Dataset Extended (Date).csv'
# -------------------------------------------------------------------------

df = pd.read_csv(df_file_path)

df.head()
# print(df.info())
# Out:
#    Daily LE      Date        B1        B2        B3        B4        B5  \
# 0   5156.32  20131207  0.497804  0.485867  0.454756  0.452261  0.566240
# 1   5156.32  20131207  0.496765  0.484919  0.453825  0.451403  0.565087
# 2   6282.30  20131223  0.453684  0.451080  0.428183  0.432599  0.586718
# 3   6282.30  20131223  0.464541  0.462078  0.439688  0.444478  0.598045
# 4   6850.13  20140209  0.152457  0.129961  0.115597  0.087031  0.332401
#
#          B6        B7        B8        B9         B10         B11     BQA  \
# 0  0.189162  0.186980  0.454444  0.135647  238.920853  239.945053  6896.0
# 1  0.188718  0.186651  0.453603  0.135376  238.902222  239.925430  6896.0
# 2  0.445939  0.331340  0.428975  0.001812  289.415314  287.303070  2800.0
# 3  0.454939  0.336979  0.438084  0.001830  289.397308  287.303070  2800.0
# 4  0.151004  0.071284  0.104161  0.029057  281.603027  278.779419  6816.0
#
#    Cloud Cover      NDVI       EVI      SAVI      VARI      NDWI
# 0        72.90  0.111908  0.448165  0.112590  0.005922 -0.109192
# 1        78.74  0.111840  0.446443  0.112448  0.005764 -0.109196
# 2        50.47  0.151199  0.482097  0.152160 -0.010779 -0.156208
# 3        81.24  0.147303  0.480300  0.149333 -0.011348 -0.152598
# 4        35.13  0.585005  0.697169  0.400307  0.393099 -0.483942

# %%
# Normalize columns (except LE)
scaler = MinMaxScaler()

# ----------- Without Date -----------
df.iloc[:, 1:] = scaler.fit_transform(df.iloc[:, 1:])
# ------------------------------------

# ------------- With Date ------------
# df.iloc[:, 2:] = scaler.fit_transform(df.iloc[:, 2:])
# ------------------------------------

df.head()
# Out:
#    Daily LE      Date        B1        B2        B3        B4        B5  \
# 0   5156.32  20131207  0.497804  0.485867  0.454756  0.452261  0.566240
# 1   5156.32  20131207  0.496765  0.484919  0.453825  0.451403  0.565087
# 2   6282.30  20131223  0.453684  0.451080  0.428183  0.432599  0.586718
# 3   6282.30  20131223  0.464541  0.462078  0.439688  0.444478  0.598045
# 4   6850.13  20140209  0.152457  0.129961  0.115597  0.087031  0.332401
#
#          B6        B7        B8        B9         B10         B11     BQA  \
# 0  0.189162  0.186980  0.454444  0.135647  238.920853  239.945053  6896.0
# 1  0.188718  0.186651  0.453603  0.135376  238.902222  239.925430  6896.0
# 2  0.445939  0.331340  0.428975  0.001812  289.415314  287.303070  2800.0
# 3  0.454939  0.336979  0.438084  0.001830  289.397308  287.303070  2800.0
# 4  0.151004  0.071284  0.104161  0.029057  281.603027  278.779419  6816.0
#
#    Cloud Cover      NDVI       EVI      SAVI      VARI      NDWI
# 0        72.90  0.111908  0.448165  0.112590  0.005922 -0.109192
# 1        78.74  0.111840  0.446443  0.112448  0.005764 -0.109196
# 2        50.47  0.151199  0.482097  0.152160 -0.010779 -0.156208
# 3        81.24  0.147303  0.480300  0.149333 -0.011348 -0.152598
# 4        35.13  0.585005  0.697169  0.400307  0.393099 -0.483942

# %%
# Split the dataset into train, validation, and test sets (using the same splits)
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.1, random_state=42)

# %%
# Calculate the mean of the 'Daily LE' column
mean_daily_le = train_data['Daily LE'].mean()

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(df.shape[1] - 1, 1)))  # Input shape for LSTM: (time_steps, input_features)
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))  # Output layer for regression

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanSquaredError(), metrics=[MeanAbsoluteError(), RSquare()])

# %%
# Prepare the data for training (reshape for LSTM)
X_train = train_data.iloc[:, 1:].values.reshape(-1, df.shape[1] - 1, 1)  # Reshape with (time_steps, input_features)
y_train = train_data['Daily LE'].values

X_val = val_data.iloc[:, 1:].values.reshape(-1, df.shape[1] - 1, 1)
y_val = val_data['Daily LE'].values

X_test = test_data.iloc[:, 1:].values.reshape(-1, df.shape[1] - 1, 1)
y_test = test_data['Daily LE'].values

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 169/169 [==============================] - 7s 30ms/step - loss: 7596187136.0000 - mean_absolute_error: 51807.6562 - r_square: -1829.2073 - val_loss: 250175856.0000 - val_mean_absolute_error: 15686.9971 - val_r_square: -60.1371
# Epoch 2/50
# 169/169 [==============================] - 10s 61ms/step - loss: 3734974208.0000 - mean_absolute_error: 29761.4395 - r_square: -898.8964 - val_loss: 42621340.0000 - val_mean_absolute_error: 5985.4849 - val_r_square: -9.4156
# Epoch 3/50
# 169/169 [==============================] - 10s 58ms/step - loss: 2182244608.0000 - mean_absolute_error: 30301.0996 - r_square: -524.7851 - val_loss: 355677312.0000 - val_mean_absolute_error: 18750.4551 - val_r_square: -85.9191
# Epoch 4/50
# 169/169 [==============================] - 11s 63ms/step - loss: 16968446.0000 - mean_absolute_error: 2639.8267 - r_square: -3.0883 - val_loss: 4159143.0000 - val_mean_absolute_error: 1540.5273 - val_r_square: -0.0164
# Epoch 5/50
# 169/169 [==============================] - 9s 55ms/step - loss: 4192498.0000 - mean_absolute_error: 1623.4860 - r_square: -0.0101 - val_loss: 4102050.2500 - val_mean_absolute_error: 1600.0604 - val_r_square: -0.0024
# Epoch 6/50
# 169/169 [==============================] - 4s 26ms/step - loss: 4224160.5000 - mean_absolute_error: 1626.8857 - r_square: -0.0178 - val_loss: 4202572.5000 - val_mean_absolute_error: 1657.7885 - val_r_square: -0.0270
# Epoch 7/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4234953.0000 - mean_absolute_error: 1630.3892 - r_square: -0.0204 - val_loss: 4172911.5000 - val_mean_absolute_error: 1644.2853 - val_r_square: -0.0198
# Epoch 8/50
# 169/169 [==============================] - 7s 39ms/step - loss: 4258541.0000 - mean_absolute_error: 1633.3501 - r_square: -0.0260 - val_loss: 4107807.5000 - val_mean_absolute_error: 1605.5593 - val_r_square: -0.0039
# Epoch 9/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4210747.0000 - mean_absolute_error: 1629.8806 - r_square: -0.0145 - val_loss: 4116490.2500 - val_mean_absolute_error: 1552.1598 - val_r_square: -0.0060
# Epoch 10/50
# 169/169 [==============================] - 5s 30ms/step - loss: 4241714.5000 - mean_absolute_error: 1631.8741 - r_square: -0.0220 - val_loss: 4091376.2500 - val_mean_absolute_error: 1579.5808 - val_r_square: 1.6427e-04
# Epoch 11/50
# 169/169 [==============================] - 6s 36ms/step - loss: 4330632.5000 - mean_absolute_error: 1640.1193 - r_square: -0.0434 - val_loss: 4122576.7500 - val_mean_absolute_error: 1616.5750 - val_r_square: -0.0075
# Epoch 12/50
# 169/169 [==============================] - 4s 27ms/step - loss: 4239737.0000 - mean_absolute_error: 1632.0974 - r_square: -0.0215 - val_loss: 4107325.7500 - val_mean_absolute_error: 1556.5819 - val_r_square: -0.0037
# Epoch 13/50
# 169/169 [==============================] - 6s 35ms/step - loss: 4399011.0000 - mean_absolute_error: 1660.8237 - r_square: -0.0599 - val_loss: 4094373.7500 - val_mean_absolute_error: 1567.9948 - val_r_square: -5.6827e-04
# Epoch 14/50
# 169/169 [==============================] - 5s 32ms/step - loss: 4302202.5000 - mean_absolute_error: 1636.7126 - r_square: -0.0366 - val_loss: 4475180.5000 - val_mean_absolute_error: 1752.7111 - val_r_square: -0.0936
# Epoch 15/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4347646.0000 - mean_absolute_error: 1646.6655 - r_square: -0.0475 - val_loss: 4507509.5000 - val_mean_absolute_error: 1534.4210 - val_r_square: -0.1015
# Epoch 16/50
# 169/169 [==============================] - 7s 39ms/step - loss: 4298043.5000 - mean_absolute_error: 1634.3265 - r_square: -0.0356 - val_loss: 4627139.0000 - val_mean_absolute_error: 1540.7330 - val_r_square: -0.1308
# Epoch 17/50
# 169/169 [==============================] - 5s 28ms/step - loss: 4374295.5000 - mean_absolute_error: 1653.4695 - r_square: -0.0539 - val_loss: 4149292.7500 - val_mean_absolute_error: 1632.3514 - val_r_square: -0.0140
# Epoch 18/50
# 169/169 [==============================] - 4s 27ms/step - loss: 4398176.5000 - mean_absolute_error: 1653.0089 - r_square: -0.0597 - val_loss: 4092485.7500 - val_mean_absolute_error: 1585.3237 - val_r_square: -1.0693e-04
# Epoch 19/50
# 169/169 [==============================] - 7s 40ms/step - loss: 4406902.5000 - mean_absolute_error: 1665.0065 - r_square: -0.0618 - val_loss: 5091620.5000 - val_mean_absolute_error: 1582.9020 - val_r_square: -0.2443
# Epoch 20/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4779126.0000 - mean_absolute_error: 1706.8157 - r_square: -0.1515 - val_loss: 4368931.5000 - val_mean_absolute_error: 1719.2651 - val_r_square: -0.0677
# Epoch 21/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4530064.0000 - mean_absolute_error: 1676.9304 - r_square: -0.0915 - val_loss: 4477341.5000 - val_mean_absolute_error: 1753.3571 - val_r_square: -0.0942
# Epoch 22/50
# 169/169 [==============================] - 7s 40ms/step - loss: 4439591.0000 - mean_absolute_error: 1667.2756 - r_square: -0.0697 - val_loss: 4655903.0000 - val_mean_absolute_error: 1542.6625 - val_r_square: -0.1378
# Epoch 23/50
# 169/169 [==============================] - 5s 30ms/step - loss: 4500164.0000 - mean_absolute_error: 1671.6265 - r_square: -0.0843 - val_loss: 4526837.5000 - val_mean_absolute_error: 1767.9152 - val_r_square: -0.1063
# Epoch 24/50
# 169/169 [==============================] - 5s 31ms/step - loss: 5090040.0000 - mean_absolute_error: 1773.6771 - r_square: -0.2264 - val_loss: 5128308.0000 - val_mean_absolute_error: 1922.6036 - val_r_square: -0.2532
# Epoch 25/50
# 169/169 [==============================] - 6s 35ms/step - loss: 4394665.5000 - mean_absolute_error: 1650.3007 - r_square: -0.0588 - val_loss: 4373117.5000 - val_mean_absolute_error: 1530.2740 - val_r_square: -0.0687
# Epoch 26/50
# 169/169 [==============================] - 4s 26ms/step - loss: 4561085.5000 - mean_absolute_error: 1685.4248 - r_square: -0.0989 - val_loss: 5482715.5000 - val_mean_absolute_error: 2003.5154 - val_r_square: -0.3398
# Epoch 27/50
# 169/169 [==============================] - 6s 34ms/step - loss: 4738665.0000 - mean_absolute_error: 1709.8226 - r_square: -0.1417 - val_loss: 5161425.0000 - val_mean_absolute_error: 1930.4746 - val_r_square: -0.2613
# Epoch 28/50
# 169/169 [==============================] - 6s 33ms/step - loss: 5074019.5000 - mean_absolute_error: 1772.0126 - r_square: -0.2225 - val_loss: 6814308.5000 - val_mean_absolute_error: 2281.2727 - val_r_square: -0.6653
# Epoch 29/50
# 169/169 [==============================] - 4s 26ms/step - loss: 5239217.5000 - mean_absolute_error: 1796.2186 - r_square: -0.2623 - val_loss: 4267625.0000 - val_mean_absolute_error: 1684.0468 - val_r_square: -0.0429
# Epoch 30/50
# 169/169 [==============================] - 6s 37ms/step - loss: 4800872.0000 - mean_absolute_error: 1722.3427 - r_square: -0.1567 - val_loss: 8293565.0000 - val_mean_absolute_error: 2081.0239 - val_r_square: -1.0268
# Epoch 31/50
# 169/169 [==============================] - 5s 30ms/step - loss: 5223713.0000 - mean_absolute_error: 1789.7467 - r_square: -0.2586 - val_loss: 4401188.0000 - val_mean_absolute_error: 1729.6672 - val_r_square: -0.0755
# Epoch 32/50
# 169/169 [==============================] - 5s 27ms/step - loss: 4870050.5000 - mean_absolute_error: 1734.8555 - r_square: -0.1734 - val_loss: 6111460.5000 - val_mean_absolute_error: 2137.7368 - val_r_square: -0.4935
# Epoch 33/50
# 169/169 [==============================] - 7s 40ms/step - loss: 5605843.0000 - mean_absolute_error: 1850.3677 - r_square: -0.3507 - val_loss: 4222252.5000 - val_mean_absolute_error: 1666.1162 - val_r_square: -0.0318
# Epoch 34/50
# 169/169 [==============================] - 6s 33ms/step - loss: 5320589.0000 - mean_absolute_error: 1815.7632 - r_square: -0.2819 - val_loss: 4216515.0000 - val_mean_absolute_error: 1533.6254 - val_r_square: -0.0304
# Epoch 35/50
# 169/169 [==============================] - 5s 28ms/step - loss: 6236162.0000 - mean_absolute_error: 1966.9435 - r_square: -0.5025 - val_loss: 8672860.0000 - val_mean_absolute_error: 2627.1455 - val_r_square: -1.1194
# Epoch 36/50
# 169/169 [==============================] - 6s 37ms/step - loss: 6001590.0000 - mean_absolute_error: 1930.2632 - r_square: -0.4460 - val_loss: 4107778.2500 - val_mean_absolute_error: 1556.3204 - val_r_square: -0.0038
# Epoch 37/50
# 169/169 [==============================] - 4s 26ms/step - loss: 5188561.5000 - mean_absolute_error: 1787.6276 - r_square: -0.2501 - val_loss: 6328530.5000 - val_mean_absolute_error: 2183.2102 - val_r_square: -0.5465
# Epoch 38/50
# 169/169 [==============================] - 5s 29ms/step - loss: 5375251.0000 - mean_absolute_error: 1817.7727 - r_square: -0.2951 - val_loss: 4127915.7500 - val_mean_absolute_error: 1547.9714 - val_r_square: -0.0088
# Epoch 39/50
# 169/169 [==============================] - 6s 37ms/step - loss: 6163022.5000 - mean_absolute_error: 1965.2638 - r_square: -0.4849 - val_loss: 8954529.0000 - val_mean_absolute_error: 2675.7808 - val_r_square: -1.1883
# Epoch 40/50
# 169/169 [==============================] - 5s 27ms/step - loss: 5810499.5000 - mean_absolute_error: 1885.3505 - r_square: -0.4000 - val_loss: 4095692.0000 - val_mean_absolute_error: 1566.0316 - val_r_square: -8.9037e-04
# Epoch 41/50
# 169/169 [==============================] - 6s 33ms/step - loss: 6596591.5000 - mean_absolute_error: 2023.8367 - r_square: -0.5894 - val_loss: 4809674.0000 - val_mean_absolute_error: 1844.9686 - val_r_square: -0.1754
# Epoch 42/50
# 169/169 [==============================] - 6s 33ms/step - loss: 5520262.5000 - mean_absolute_error: 1850.6438 - r_square: -0.3300 - val_loss: 4686810.5000 - val_mean_absolute_error: 1812.3918 - val_r_square: -0.1453
# Epoch 43/50
# 169/169 [==============================] - 5s 27ms/step - loss: 5220799.5000 - mean_absolute_error: 1787.8014 - r_square: -0.2579 - val_loss: 4547263.5000 - val_mean_absolute_error: 1536.1595 - val_r_square: -0.1112
# Epoch 44/50
# 169/169 [==============================] - 6s 36ms/step - loss: 7239455.5000 - mean_absolute_error: 2107.6238 - r_square: -0.7443 - val_loss: 4100697.5000 - val_mean_absolute_error: 1560.9940 - val_r_square: -0.0021
# Epoch 45/50
# 169/169 [==============================] - 5s 30ms/step - loss: 6021993.5000 - mean_absolute_error: 1937.1205 - r_square: -0.4509 - val_loss: 5286039.0000 - val_mean_absolute_error: 1604.1262 - val_r_square: -0.2918
# Epoch 46/50
# 169/169 [==============================] - 5s 27ms/step - loss: 5901710.0000 - mean_absolute_error: 1902.1866 - r_square: -0.4219 - val_loss: 6147558.5000 - val_mean_absolute_error: 2145.2986 - val_r_square: -0.5023
# Epoch 47/50
# 169/169 [==============================] - 7s 41ms/step - loss: 5561847.5000 - mean_absolute_error: 1848.2506 - r_square: -0.3401 - val_loss: 4623572.5000 - val_mean_absolute_error: 1540.5011 - val_r_square: -0.1299
# Epoch 48/50
# 169/169 [==============================] - 5s 27ms/step - loss: 5854212.0000 - mean_absolute_error: 1903.1771 - r_square: -0.4105 - val_loss: 4095234.2500 - val_mean_absolute_error: 1566.6619 - val_r_square: -7.7856e-04
# Epoch 49/50
# 169/169 [==============================] - 4s 26ms/step - loss: 6645432.5000 - mean_absolute_error: 2004.0090 - r_square: -0.6011 - val_loss: 4113202.7500 - val_mean_absolute_error: 1553.5669 - val_r_square: -0.0052
# Epoch 50/50
# 169/169 [==============================] - 7s 40ms/step - loss: 5846721.0000 - mean_absolute_error: 1903.2007 - r_square: -0.4087 - val_loss: 4485380.0000 - val_mean_absolute_error: 1755.7515 - val_r_square: -0.0961

# %%
# Evaluate the model on the test set
test_loss, test_mae, test_r_squared = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}, Test R-squared: {test_r_squared}")
# Out:
# 47/47 [==============================] - 1s 18ms/step - loss: 4471760.0000 - mean_absolute_error: 1808.3127 - r_square: -0.1121
# Test Loss: 4471760.0, Test MAE: 1808.312744140625, Test R-squared: -0.11214816570281982

# %%
# Calculate normalized performance metrics
normalized_test_loss = test_loss / mean_daily_le
normalized_test_mae = test_mae / mean_daily_le

print(f"Normalized Test Loss: {normalized_test_loss * 100}%")
print(f"Normalized Test MAE: {normalized_test_mae * 100}%")
# Out:
# Normalized Test Loss: 197929.04414766934%
# Normalized Test MAE: 80.03953990549645%

# %%
# Access the training history
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(training_loss) + 1)

# Plot training and validation loss
plt.plot(epochs, training_loss, 'bo', label='Training Loss')
plt.plot(epochs, validation_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# Create a regression plot
sns.regplot(x=y_test, y=y_pred)
plt.xlabel('Actual Daily LE')
plt.ylabel('Predicted Daily LE')
plt.title('Regression Plot')
plt.show()
# Out:
# 47/47 [==============================] - 1s 15ms/step
